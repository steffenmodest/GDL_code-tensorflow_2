# %% [markdown]
# # Autoencoder

# %%
# !git clone https://github.com/steffenmodest/GDL_code-tensorflow_2.git
# Out:
# Cloning into 'GDL_code-tensorflow_2'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 59 (delta 19), reused 59 (delta 19), pack-reused 0
# Unpacking objects: 100% (59/59), done.

# %%
import sys
sys.path.append('/content/GDL_code-tensorflow_2')

# %%
import os

from utils.loaders import load_mnist
from models.AE import Autoencoder

# %% [markdown]
# ## Set parameters

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = '/content/GDL_code-tensorflow_2/run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

MODE =  'build' #'load' #

# %% [markdown]
# ## Load the data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## Define the structure of the neural network

# %%
AE = Autoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if MODE == 'build':
    AE.save(RUN_FOLDER)
else:
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
AE.encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 28, 28, 1)]       0
# _________________________________________________________________
# encoder_conv_0 (Conv2D)      (None, 28, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 28, 28, 32)        0
# _________________________________________________________________
# encoder_conv_1 (Conv2D)      (None, 14, 14, 64)        18496
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# encoder_conv_2 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# encoder_conv_3 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 6274
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the autoencoder

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH = 0

# %%
AE.compile(LEARNING_RATE)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
AE.train(     
    x_train[:1000]
    , batch_size = BATCH_SIZE
    , epochs = 200
    , run_folder = RUN_FOLDER
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 5s 116ms/step - loss: 0.1849
#
# Epoch 00001: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 2/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.1030
#
# Epoch 00002: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 3/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0744
#
# Epoch 00003: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 4/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0637
#
# Epoch 00004: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 5/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0589
#
# Epoch 00005: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 6/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0570
#
# Epoch 00006: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 7/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0558
#
# Epoch 00007: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 8/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0548
#
# Epoch 00008: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 9/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0539
#
# Epoch 00009: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 10/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0532
#
# Epoch 00010: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 11/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0527
#
# Epoch 00011: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 12/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0523
#
# Epoch 00012: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 13/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0517
#
# Epoch 00013: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 14/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0514
#
# Epoch 00014: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 15/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0510
#
# Epoch 00015: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 16/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0508
#
# Epoch 00016: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 17/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0503
#
# Epoch 00017: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 18/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0500
#
# Epoch 00018: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 19/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0497
#
# Epoch 00019: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 20/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0495
#
# Epoch 00020: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 21/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0494
#
# Epoch 00021: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 22/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0490
#
# Epoch 00022: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 23/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0486
#
# Epoch 00023: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 24/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0482
#
# Epoch 00024: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 25/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0481
#
# Epoch 00025: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 26/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0480
#
# Epoch 00026: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 27/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0476
#
# Epoch 00027: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 28/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0473
#
# Epoch 00028: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 29/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0474
#
# Epoch 00029: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 30/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0473
#
# Epoch 00030: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 31/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0469
#
# Epoch 00031: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 32/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0469
#
# Epoch 00032: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 33/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.0463
#
# Epoch 00033: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 34/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0462
#
# Epoch 00034: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 35/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0461
#
# Epoch 00035: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 36/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.0461
#
# Epoch 00036: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 37/200
# 32/32 [==============================] - 4s 109ms/step - loss: 0.0457
#
# Epoch 00037: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 38/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0456
#
# Epoch 00038: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 39/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0453
#
# Epoch 00039: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 40/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0453
#
# Epoch 00040: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 41/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0450
#
# Epoch 00041: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 42/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0452
#
# Epoch 00042: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 43/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0449
#
# Epoch 00043: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 44/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0447
#
# Epoch 00044: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 45/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0446
#
# Epoch 00045: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 46/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0444
#
# Epoch 00046: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch
saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 84/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0395
#
# Epoch 00084: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 85/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0394
#
# Epoch 00085: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 86/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0396
#
# Epoch 00086: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 87/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0397
#
# Epoch 00087: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 88/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0393
#
# Epoch 00088: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 89/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0389
#
# Epoch 00089: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 90/200
# 32/32 [==============================] - 4s 111ms/step - loss: 0.0390
#
# Epoch 00090: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 91/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0388
#
# Epoch 00091: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 92/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0387
#
# Epoch 00092: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 93/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0389
#
# Epoch 00093: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 94/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0388
#
# Epoch 00094: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 95/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0389
#
# Epoch 00095: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 96/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0389
#
# Epoch 00096: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 97/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0387
#
# Epoch 00097: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 98/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0390
#
# Epoch 00098: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 99/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0388
#
# Epoch 00099: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 100/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0387
#
# Epoch 00100: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 101/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0385
#
# Epoch 00101: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 102/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0382
#
# Epoch 00102: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 103/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0382
#
# Epoch 00103: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 104/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0386
#
# Epoch 00104: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 105/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0383
#
# Epoch 00105: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 106/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0379
#
# Epoch 00106: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 107/200
# 32/32 [==============================] - 4s 112ms/step - loss: 0.0378
#
# Epoch 00107: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 108/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0378
#
# Epoch 00108: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 109/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0378
#
# Epoch 00109: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 110/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0376
#
# Epoch 00110: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 111/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0375
#
# Epoch 00111: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 112/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0377
#
# Epoch 00112: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 113/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0376
#
# Epoch 00113: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 114/200
# 32/32 [==============================] - 4s 116ms/step - loss: 0.0377
#
# Epoch 00114: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 115/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0376
#
# Epoch 00115: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 116/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0373
#
# Epoch 00116: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 117/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0371
#
# Epoch 00117: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 118/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0376
#
# Epoch 00118: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 119/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0372
#
# Epoch 00119: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 120/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0370
#
# Epoch 00120: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 121/200
# 32/32 [==============================] - 4s 114ms/step - loss: 0.0372
#
# Epoch 00121: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 122/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0370
#
# Epoch 00122: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 123/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0368
#
# Epoch 00123: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 124/200
# 32/32 [==============================] - 4s 113ms/step - loss: 0.0368
#
# Epoch 00124: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 125/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0367
#
# Epoch 00125: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 126/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0366
#
# Epoch 00126: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 127/200
# 32/32 [==============================] - 4s 115ms/step - loss: 0.0366
#
# Epoch 00127: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch 128/200
# 32/32 [==============================] - 4s 116ms/step - loss: 0.0366
#
# Epoch 00128: saving model to /content/GDL_code-tensorflow_2/run/vae/0001_digits/weights/weights.h5
# Epoch