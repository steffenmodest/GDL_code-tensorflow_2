# %% [markdown]
# # VAE Training

# %% [markdown]
# ## imports

# %%
# !git clone https://github.com/steffenmodest/GDL_code-tensorflow_2.git
# Out:
# Cloning into 'GDL_code-tensorflow_2'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 74 (delta 28), reused 63 (delta 23), pack-reused 0
# Unpacking objects: 100% (74/74), done.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/content/GDL_code-tensorflow_2')

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
# RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER = '/content/GDL_code-tensorflow_2/run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %%
RUN_FOLDER
# Out:
# '/content/GDL_code-tensorflow_2/run/vae/0002_digits'

# %% [markdown]
# ## data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## architecture

# %%
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
    , r_loss_factor = 1000
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
RUN_FOLDER
# Out:
# '/content/GDL_code-tensorflow_2/run/vae/0002_digits'

# %%
vae.encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3136)         0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten[0][0]
# __________________________________________________________________________________________________
# encoder_output (Sampling)       (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
LEARNING_RATE = 0.0005

# %%
vae.compile(LEARNING_RATE)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/200
#    4/1875 [..............................] - ETA: 31s - loss: 44.3378 - reconstruction_loss: 39.4385 - kl_loss: 4.8992WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0038s vs `on_train_batch_end` time: 0.0071s). Check your callbacks.
# 1875/1875 [==============================] - 8s 4ms/step - loss: 47.3298 - reconstruction_loss: 42.5155 - kl_loss: 4.8143
#
# Epoch 00001: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00001: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 2/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 47.0847 - reconstruction_loss: 42.2308 - kl_loss: 4.8539
#
# Epoch 00002: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00002: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 3/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.8783 - reconstruction_loss: 41.9826 - kl_loss: 4.8958
#
# Epoch 00003: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00003: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 4/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.6778 - reconstruction_loss: 41.7443 - kl_loss: 4.9335
#
# Epoch 00004: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00004: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 5/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.5349 - reconstruction_loss: 41.5661 - kl_loss: 4.9687
#
# Epoch 00005: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00005: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 6/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.3753 - reconstruction_loss: 41.3792 - kl_loss: 4.9961
#
# Epoch 00006: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00006: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 7/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.1990 - reconstruction_loss: 41.1857 - kl_loss: 5.0133
#
# Epoch 00007: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00007: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 8/200
# 1875/1875 [==============================] - 8s 5ms/step - loss: 46.0777 - reconstruction_loss: 41.0309 - kl_loss: 5.0469
#
# Epoch 00008: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00008: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 9/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 46.0041 - reconstruction_loss: 40.9415 - kl_loss: 5.0626
#
# Epoch 00009: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00009: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 10/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 45.9244 - reconstruction_loss: 40.8536 - kl_loss: 5.0708
#
# Epoch 00010: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00010: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 11/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 45.7835 - reconstruction_loss: 40.6931 - kl_loss: 5.0903
#
# Epoch 00011: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00011: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 12/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 45.7024 - reconstruction_loss: 40.5920 - kl_loss: 5.1104
#
# Epoch 00012: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00012: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 13/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 45.6082 - reconstruction_loss: 40.4848 - kl_loss: 5.1234
#
# Epoch 00013: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00013: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 14/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 45.5449 - reconstruction_loss: 40.3967 - kl_loss: 5.1482
#
# Epoch 00014: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00014: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 15/200
# 1875/1875 [==============================] - 8s 5ms/step - loss: 45.4775 - reconstruction_loss: 40.3235 - kl_loss: 5.1540
#
# Epoch 00015: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 
saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00040: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 41/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.3978 - reconstruction_loss: 39.0520 - kl_loss: 5.3458
#
# Epoch 00041: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00041: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 42/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.3627 - reconstruction_loss: 39.0081 - kl_loss: 5.3546
#
# Epoch 00042: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00042: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 43/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 44.3318 - reconstruction_loss: 38.9970 - kl_loss: 5.3348
#
# Epoch 00043: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00043: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 44/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 44.3056 - reconstruction_loss: 38.9500 - kl_loss: 5.3556
#
# Epoch 00044: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00044: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 45/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.2654 - reconstruction_loss: 38.9054 - kl_loss: 5.3601
#
# Epoch 00045: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00045: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 46/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.2778 - reconstruction_loss: 38.9140 - kl_loss: 5.3638
#
# Epoch 00046: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00046: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 47/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.2039 - reconstruction_loss: 38.8347 - kl_loss: 5.3692
#
# Epoch 00047: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00047: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 48/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.2210 - reconstruction_loss: 38.8586 - kl_loss: 5.3624
#
# Epoch 00048: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00048: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 49/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.1991 - reconstruction_loss: 38.8285 - kl_loss: 5.3706
#
# Epoch 00049: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00049: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 50/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.1652 - reconstruction_loss: 38.7961 - kl_loss: 5.3691
#
# Epoch 00050: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00050: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 51/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 44.1304 - reconstruction_loss: 38.7673 - kl_loss: 5.3631
#
# Epoch 00051: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00051: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 52/200
# 1875/1875 [==============================] - 8s 5ms/step - loss: 44.1098 - reconstruction_loss: 38.7334 - kl_loss: 5.3764
#
# Epoch 00052: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00052: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 53/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.1008 - reconstruction_loss: 38.7265 - kl_loss: 5.3743
#
# Epoch 00053: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00053: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 54/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.0971 - reconstruction_loss: 38.7168 - kl_loss: 5.3803
#
# Epoch 00054: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00054: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 55/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.0698 - reconstruction_loss: 38.6837 - kl_loss: 5.3861
#
# Epoch 00055: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00055: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 56/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.0174 - reconstruction_loss: 38.6327 - kl_loss: 5.3848
#
# Epoch 00056: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00056: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 57/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 44.0127 - reconstruction_loss: 38.6209 - kl_loss: 5.3918
#
# Epoch 00057: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00057: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 58/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 44.0013 - reconstruction_loss: 38.6010 - kl_loss: 5.4003
#
# Epoch 00058: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00058: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 59/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.9933 - reconstruction_loss: 38.6023 - kl_loss: 5.3910
#
# Epoch 00059: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00059: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 60/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.9754 - reconstruction_loss: 38.5569 - kl_loss: 5.4186
#
# Epoch 00060: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00060: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 61/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.9523 - reconstruction_loss: 38.5582 - kl_loss: 5.3941
#
# Epoch 00061: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00061: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 62/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.9403 - reconstruction_loss: 38.5309 - kl_loss: 5.4094
#
# Epoch 00062: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00062: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 63/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.9417 - reconstruction_loss: 38.5370 - kl_loss: 5.4046
#
# Epoch 00063: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00063: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 64/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.8998 - reconstruction_loss: 38.4929 - kl_loss: 5.4069
#
# Epoch 00064: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00064: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 65/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.8884 - reconstruction_loss: 38.4810 - kl_loss: 5.4074
#
# Epoch 00065: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00065: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 66/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.8565 - reconstruction_loss: 38.4487 - kl_loss: 5.4078
#
# Epoch 00066: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00066: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 67/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.8901 - reconstruction_loss: 38.4771 - kl_loss: 5.4130
#
# Epoch 00067: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00067: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 68/200
# 1875/1875 [==============================] - 8s 5ms/step - loss: 43.8112 - reconstruction_loss: 38.4084 - kl_loss: 5.4028
#
# Epoch 00068: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00068: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 69/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.8561 - reconstruction_loss: 38.4262 - kl_loss: 5.4299
#
# Epoch 00069: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00069: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 70/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.8401 - reconstruction_loss: 38.4099 - kl_loss: 5.4302
#
# Epoch 00070: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00070: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 71/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.8195 - reconstruction_loss: 38.3895 - kl_loss: 5.4301
#
# Epoch 00071: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00071: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 72/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7960 - reconstruction_loss: 38.3579 - kl_loss: 5.4381
#
# Epoch 00072: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00072: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 73/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7735 - reconstruction_loss: 38.3412 - kl_loss: 5.4323
#
# Epoch 00073: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00073: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 74/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7292 - reconstruction_loss: 38.2952 - kl_loss: 5.4340
#
# Epoch 00074: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00074: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 75/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7334 - reconstruction_loss: 38.3060 - kl_loss: 5.4274
#
# Epoch 00075: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00075: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 76/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7594 - reconstruction_loss: 38.3172 - kl_loss: 5.4423
#
# Epoch 00076: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00076: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 77/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.7099 - reconstruction_loss: 38.2638 - kl_loss: 5.4461
#
# Epoch 00077: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00077: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 78/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.6996 - reconstruction_loss: 38.2638 - kl_loss: 5.4358
#
# Epoch 00078: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00078: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 79/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.7036 - reconstruction_loss: 38.2589 - kl_loss: 5.4447
#
# Epoch 00079: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00079: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 80/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6740 - reconstruction_loss: 38.2264 - kl_loss: 5.4475
#
# Epoch 00080: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00080: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 81/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6721 - reconstruction_loss: 38.2085 - kl_loss: 5.4636
#
# Epoch 00081: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00081: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 82/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6545 - reconstruction_loss: 38.2143 - kl_loss: 5.4403
#
# Epoch 00082: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00082: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 83/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6459 - reconstruction_loss: 38.2034 - kl_loss: 5.4425
#
# Epoch 00083: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00083: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 84/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6311 - reconstruction_loss: 38.1689 - kl_loss: 5.4622
#
# Epoch 00084: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00084: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 85/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.6681 - reconstruction_loss: 38.2128 - kl_loss: 5.4553
#
# Epoch 00085: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00085: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 86/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.5841 - reconstruction_loss: 38.1216 - kl_loss: 5.4625
#
# Epoch 00086: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00086: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 87/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.6079 - reconstruction_loss: 38.1483 - kl_loss: 5.4595
#
# Epoch 00087: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00087: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 88/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5827 - reconstruction_loss: 38.1218 - kl_loss: 5.4609
#
# Epoch 00088: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00088: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 89/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5850 - reconstruction_loss: 38.1128 - kl_loss: 5.4722
#
# Epoch 00089: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00089: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 90/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5639 - reconstruction_loss: 38.0915 - kl_loss: 5.4724
#
# Epoch 00090: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00090: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 91/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5019 - reconstruction_loss: 38.0271 - kl_loss: 5.4747
#
# Epoch 00091: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00091: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 92/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5319 - reconstruction_loss: 38.0681 - kl_loss: 5.4638
#
# Epoch 00092: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00092: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 93/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43.5432 - reconstruction_loss: 38.0750 - kl_loss: 5.4682
#
# Epoch 00093: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00093: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 94/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.5299 - reconstruction_loss: 38.0598 - kl_loss: 5.4701
#
# Epoch 00094: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00094: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 95/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 43.5108 - reconstruction_loss: 38.0456 - kl_loss: 5.4652
#
# Epoch 00095: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00095: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 96/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 43
200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8759 - reconstruction_loss: 37.3023 - kl_loss: 5.5736
#
# Epoch 00190: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00190: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 191/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 42.8656 - reconstruction_loss: 37.2944 - kl_loss: 5.5712
#
# Epoch 00191: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00191: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 192/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 42.8803 - reconstruction_loss: 37.3088 - kl_loss: 5.5715
#
# Epoch 00192: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00192: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 193/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 42.8583 - reconstruction_loss: 37.2887 - kl_loss: 5.5696
#
# Epoch 00193: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00193: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 194/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8824 - reconstruction_loss: 37.3057 - kl_loss: 5.5768
#
# Epoch 00194: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00194: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 195/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8345 - reconstruction_loss: 37.2645 - kl_loss: 5.5700
#
# Epoch 00195: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00195: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 196/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8605 - reconstruction_loss: 37.2743 - kl_loss: 5.5862
#
# Epoch 00196: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00196: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 197/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8325 - reconstruction_loss: 37.2491 - kl_loss: 5.5835
#
# Epoch 00197: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00197: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 198/200
# 1875/1875 [==============================] - 8s 4ms/step - loss: 42.8365 - reconstruction_loss: 37.2613 - kl_loss: 5.5753
#
# Epoch 00198: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00198: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 199/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 42.8496 - reconstruction_loss: 37.2651 - kl_loss: 5.5844
#
# Epoch 00199: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00199: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
# Epoch 200/200
# 1875/1875 [==============================] - 9s 5ms/step - loss: 42.8490 - reconstruction_loss: 37.2778 - kl_loss: 5.5712
#
# Epoch 00200: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5
#
# Epoch 00200: saving model to /content/GDL_code-tensorflow_2/run/vae/0002_digits/weights/weights.h5

# %%
# vae.save(RUN_FOLDER)

# %% [markdown]
# # VAE Analysis

# %% [markdown]
# ## imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist, load_model

# %%
# # run params
# SECTION = 'vae'
# RUN_ID = '0002'
# DATA_NAME = 'digits'
# # RUN_FOLDER = 'run/{}/'.format(SECTION)
# RUN_FOLDER = '/content/GDL_code-tensorflow_2/run/{}/'.format(SECTION)
# RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

# %% [markdown]
# ## data

# %%
# (x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## architecture

# %%
# vae = load_model(VariationalAutoencoder, RUN_FOLDER)

# %% [markdown]
# ## reconstructing original paintings

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
            
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img, cmap='gray_r')

# %% [markdown]
# ## Mr N. Coder's wall

# %%
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %% [markdown]
# ### The new generated art exhibition

# %%
figsize = 8
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=5)



plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

_,_,z_points = vae.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = norm.ppf(np.linspace(0.01, 0.99, grid_size))
y = norm.ppf(np.linspace(0.01, 0.99, grid_size))
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=2)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
